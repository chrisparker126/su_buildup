# %%
import numpy as np

from keras.models import Sequential
import cv2
import matplotlib.pyplot as plt
import csv
from ucf101_datagenerator.generator_class import DataGenerator
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
# Parameters
params = { 'data_dir' : "/data/ucf101",
          'dim': (224,224),
          'batch_size': 64,
          'n_classes': 101,
          'n_channels': 3,
          'shuffle': True}

# %%
# load Id list and labels 

train_list = list()

with open('./ucf101_splits/trainlist01.txt', 'r') as f:
    reader = csv.reader(f)
    train_list = list(reader)

# %%
labels = [int(label[0].split(' ')[1]) for label in train_list ]
IDs = [label[0].split(' ')[0] for label in train_list ]
# IDs
IDs = [id.split('/')[1].rstrip('.avi') for id in IDs ]

labels = dict(zip(IDs, labels))
labels
# Out:
# {'v_ApplyEyeMakeup_g08_c01': 1,
#  'v_ApplyEyeMakeup_g08_c02': 1,
#  'v_ApplyEyeMakeup_g08_c03': 1,
#  'v_ApplyEyeMakeup_g08_c04': 1,
#  'v_ApplyEyeMakeup_g08_c05': 1,
#  'v_ApplyEyeMakeup_g09_c01': 1,
#  'v_ApplyEyeMakeup_g09_c02': 1,
#  'v_ApplyEyeMakeup_g09_c03': 1,
#  'v_ApplyEyeMakeup_g09_c04': 1,
#  'v_ApplyEyeMakeup_g09_c05': 1,
#  'v_ApplyEyeMakeup_g09_c06': 1,
#  'v_ApplyEyeMakeup_g09_c07': 1,
#  'v_ApplyEyeMakeup_g10_c01': 1,
#  'v_ApplyEyeMakeup_g10_c02': 1,
#  'v_ApplyEyeMakeup_g10_c03': 1,
#  'v_ApplyEyeMakeup_g10_c04': 1,
#  'v_ApplyEyeMakeup_g10_c05': 1,
#  'v_ApplyEyeMakeup_g11_c01': 1,
#  'v_ApplyEyeMakeup_g11_c02': 1,
#  'v_ApplyEyeMakeup_g11_c03': 1,
#  'v_ApplyEyeMakeup_g11_c04': 1,
#  'v_ApplyEyeMakeup_g11_c05': 1,
#  'v_ApplyEyeMakeup_g12_c01': 1,
#  'v_ApplyEyeMakeup_g12_c02': 1,
#  'v_ApplyEyeMakeup_g12_c03': 1,
#  'v_ApplyEyeMakeup_g12_c04': 1,
#  'v_ApplyEyeMakeup_g12_c05': 1,
#  'v_ApplyEyeMakeup_g12_c06': 1,
#  'v_ApplyEyeMakeup_g13_c01': 1,
#  'v_ApplyEyeMakeup_g13_c02': 1,
#  'v_ApplyEyeMakeup_g13_c03': 1,
#  'v_ApplyEyeMakeup_g13_c04': 1,
#  'v_ApplyEyeMakeup_g13_c05': 1,
#  'v_ApplyEyeMakeup_g13_c06': 1,
#  'v_ApplyEyeMakeup_g14_c01': 1,
#  'v_ApplyEyeMakeup_g14_c02': 1,
#  'v_ApplyEyeMakeup_g14_c03': 1,
#  'v_ApplyEyeMakeup_g14_c04': 1,
#  'v_ApplyEyeMakeup_g14_c05': 1,
#  'v_ApplyEyeMakeup_g15_c01': 1,
#  'v_ApplyEyeMakeup_g15_c02': 1,
#  'v_ApplyEyeMakeup_g15_c03': 1,
#  'v_ApplyEyeMakeup_g15_c04': 1,
#  'v_ApplyEyeMakeup_g15_c05': 1,
#  'v_ApplyEyeMakeup_g15_c06': 1,
#  'v_ApplyEyeMakeup_g15_c07': 1,
#  'v_ApplyEyeMakeup_g16_c01': 1,
#  'v_ApplyEyeMakeup_g16_c02': 1,
#  'v_ApplyEyeMakeup_g16_c03': 1,
#  'v_ApplyEyeMakeup_g16_c04': 1,
#  'v_ApplyEyeMakeup_g16_c05': 1,
#  'v_ApplyEyeMakeup_g17_c01': 1,
#  'v_ApplyEyeMakeup_g17_c02': 1,
#  'v_ApplyEyeMakeup_g17_c03': 1,
#  'v_ApplyEyeMakeup_g17_c04': 1,
#  'v_ApplyEyeMakeup_g17_c05': 1,
#  'v_ApplyEyeMakeup_g18_c01': 1,
#  'v_ApplyEyeMakeup_g18_c02': 1,
#  'v_ApplyEyeMakeup_g18_c03': 1,
#  'v_ApplyEyeMakeup_g18_c04': 1,
#  'v_ApplyEyeMakeup_g18_c05': 1,
#  'v_ApplyEyeMakeup_g19_c01': 1,
#  'v_ApplyEyeMakeup_g19_c02': 1,
#  'v_ApplyEyeMakeup_g19_c03': 1,
#  'v_ApplyEyeMakeup_g19_c04': 1,
#  'v_ApplyEyeMakeup_g20_c01': 1,
#  'v_ApplyEyeMakeup_g20_c02': 1,
#  'v_ApplyEyeMakeup_g20_c03': 1,
#  'v_ApplyEyeMakeup_g20_c04': 1,
#  'v_ApplyEyeMakeup_g20_c05': 1,
#  'v_ApplyEyeMakeup_g20_c06': 1,
#  'v_ApplyEyeMakeup_g21_c01': 1,
#  'v_ApplyEyeMakeup_g21_c02': 1,
#  'v_ApplyEyeMakeup_g21_c03': 1,
#  'v_ApplyEyeMakeup_g21_c04': 1,
#  'v_ApplyEyeMakeup_g21_c05': 1,
#  'v_ApplyEyeMakeup_g22_c01': 1,
#  'v_ApplyEyeMakeup_g22_c02': 1,
#  'v_ApplyEyeMakeup_g22_c03': 1,
#  'v_ApplyEyeMakeup_g22_c04': 1,
#  'v_ApplyEyeMakeup_g22_c05': 1,
#  'v_ApplyEyeMakeup_g23_c01': 1,
#  'v_ApplyEyeMakeup_g23_c02': 1,
#  'v_ApplyEyeMakeup_g23_c03': 1,
#  'v_ApplyEyeMakeup_g23_c04': 1,
#  'v_ApplyEyeMakeup_g23_c05': 1,
#  'v_ApplyEyeMakeup_g23_c06': 1,
#  'v_ApplyEyeMakeup_g24_c01': 1,
#  'v_ApplyEyeMakeup_g24_c02': 1,
#  'v_ApplyEyeMakeup_g24_c03': 1,
#  'v_ApplyEyeMakeup_g24_c04': 1,
#  'v_ApplyEyeMakeup_g24_c05': 1,
#  'v_ApplyEyeMakeup_g24_c06': 1,
#  'v_ApplyEyeMakeup_g24_c07': 1,
#  'v_ApplyEyeMakeup_g25_c01': 1,
#  'v_ApplyEyeMakeup_g25_c02': 1,
#  'v_ApplyEyeMakeup_g25_c03': 1,
#  'v_ApplyEyeMakeup_g25_c04': 1,
#  'v_ApplyEyeMakeup_g25_c05': 1,
#  'v_ApplyEyeMakeup_g25_c06': 1,
#  'v_ApplyEyeMakeup_g25_c07': 1,
#  'v_ApplyLipstick_g08_c01': 2,
#  'v_ApplyLipstick_g08_c02': 2,
#  'v_ApplyLipstick_g08_c03': 2,
#  'v_ApplyLipstick_g08_c04': 2,
#  'v_ApplyLipstick_g09_c01': 2,
#  'v_ApplyLipstick_g09_c02': 2,
#  'v_ApplyLipstick_g09_c03': 2,
#  'v_ApplyLipstick_g09_c04': 2,
#  'v_ApplyLipstick_g10_c01': 2,
#  'v_ApplyLipstick_g10_c02': 2,
#  'v_ApplyLipstick_g10_c03': 2,
#  'v_ApplyLipstick_g10_c04': 2,
#  'v_ApplyLipstick_g11_c01': 2,
#  'v_ApplyLipstick_g11_c02': 2,
#  'v_ApplyLipstick_g11_c03': 2,
#  'v_ApplyLipstick_g11_c04': 2,
#  'v_ApplyLipstick_g12_c01': 2,
#  'v_ApplyLipstick_g12_c02': 2,
#  'v_ApplyLipstick_g12_c03': 2,
#  'v_ApplyLipstick_g12_c04': 2,
#  'v_ApplyLipstick_g12_c05': 2,
#  'v_ApplyLipstick_g13_c01': 2,
#  'v_ApplyLipstick_g13_c02': 2,
#  'v_ApplyLipstick_g13_c03': 2,
#  'v_ApplyLipstick_g13_c04': 2,
#  'v_ApplyLipstick_g14_c01': 2,
#  'v_ApplyLipstick_g14_c02': 2,
#  'v_ApplyLipstick_g14_c03': 2,
#  'v_ApplyLipstick_g14_c04': 2,
#  'v_ApplyLipstick_g15_c01': 2,
#  'v_ApplyLipstick_g15_c02': 2,
#  'v_ApplyLipstick_g15_c03': 2,
#  'v_ApplyLipstick_g15_c04': 2,
#  'v_ApplyLipstick_g15_c05': 2,
#  'v_ApplyLipstick_g16_c01': 2,
#  'v_ApplyLipstick_g16_c02': 2,
#  'v_ApplyLipstick_g16_c03': 2,
#  'v_ApplyLipstick_g16_c04': 2,
#  'v_ApplyLipstick_g16_c05': 2,
#  'v_ApplyLipstick_g17_c01': 2,
#  'v_ApplyLipstick_g17_c02': 2,
#  'v_ApplyLipstick_g17_c03': 2,
#  'v_ApplyLipstick_g17_c04': 2,
#  'v_ApplyLipstick_g17_c05': 2,
#  'v_ApplyLipstick_g18_c01': 2,
#  'v_ApplyLipstick_g18_c02': 2,
#  'v_ApplyLipstick_g18_c03': 2,
#  'v_ApplyLipstick_g18_c04': 2,
#  'v_ApplyLipstick_g19_c01': 2,
#  'v_ApplyLipstick_g19_c02': 2,
#  'v_ApplyLipstick_g19_c03': 2,
#  'v_ApplyLipstick_g19_c04': 2,
#  'v_ApplyLipstick_g20_c01': 2,
#  'v_ApplyLipstick_g20_c02': 2,
#  'v_ApplyLipstick_g20_c03': 2,
#  'v_ApplyLipstick_g20_c04': 2,
#  'v_ApplyLipstick_g20_c05': 2,
#  'v_ApplyLipstick_g21_c01': 2,
#  'v_ApplyLipstick_g21_c02': 2,
#  'v_ApplyLipstick_g21_c03': 2,
#  'v_ApplyLipstick_g21_c04': 2,
#  'v_ApplyLipstick_g21_c05': 2,
#  'v_ApplyLipstick_g22_c01': 2,
#  'v_ApplyLipstick_g22_c02': 2,
#  'v_ApplyLipstick_g22_c03': 2,
#  'v_ApplyLipstick_g22_c04': 2,
#  'v_ApplyLipstick_g22_c05': 2,
#  'v_ApplyLipstick_g22_c06': 2,
#  'v_ApplyLipstick_g22_c07': 2,
#  'v_ApplyLipstick_g23_c01': 2,
#  'v_ApplyLipstick_g23_c02': 2,
#  'v_ApplyLipstick_g23_c03': 2,
#  'v_ApplyLipstick_g23_c04': 2,
#  'v_ApplyLipstick_g24_c01': 2,
#  'v_ApplyLipstick_g24_c02': 2,
#  'v_ApplyLipstick_g24_c03': 2,
#  'v_ApplyLipstick_g24_c04': 2,
#  'v_ApplyLipstick_g24_c05': 2,
#  'v_ApplyLipstick_g25_c01': 2,
#  'v_ApplyLipstick_g25_c02': 2,
#  'v_ApplyLipstick_g25_c03': 2,
#  'v_ApplyLipstick_g25_c04': 2,
#  'v_Archery_g08_c01': 3,
#  'v_Archery_g08_c02': 3,
#  'v_Archery_g08_c03': 3,
#  'v_Archery_g08_c04': 3,
#  'v_Archery_g08_c05': 3,
#  'v_Archery_g09_c01': 3,
#  'v_Archery_g09_c02': 3,
#  'v_Archery_g09_c03': 3,
#  'v_Archery_g09_c04': 3,
#  'v_Archery_g09_c05': 3,
#  'v_Archery_g09_c06': 3,
#  'v_Archery_g09_c07': 3,
#  'v_Archery_g10_c01': 3,
#  'v_Archery_g10_c02': 3,
#  'v_Archery_g10_c03': 3,
#  'v_Archery_g10_c04': 3,
#  'v_Archery_g10_c05': 3,
#  'v_Archery_g10_c06': 3,
#  'v_Archery_g10_c07': 3,
#  'v_Archery_g11_c01': 3,
#  'v_Archery_g11_c02': 3,
#  'v_Archery_g11_c03': 3,
#  'v_Archery_g11_c04': 3,
#  'v_Archery_g11_c05': 3,
#  'v_Archery_g11_c06': 3,
#  'v_Archery_g11_c07': 3,
#  'v_Archery_g12_c01': 3,
#  'v_Archery_g12_c02': 3,
#  'v_Archery_g12_c03': 3,
#  'v_Archery_g12_c04': 3,
#  'v_Archery_g13_c01': 3,
#  'v_Archery_g13_c02': 3,
#  'v_Archery_g13_c03': 3,
#  'v_Archery_g13_c04': 3,
#  'v_Archery_g13_c05': 3,
#  'v_Archery_g13_c06': 3,
#  'v_Archery_g13_c07': 3,
#  'v_Archery_g14_c01': 3,
#  'v_Archery_g14_c02': 3,
#  'v_Archery_g14_c03': 3,
#  'v_Archery_g14_c04': 3,
#  'v_Archery_g15_c01': 3,
#  'v_Archery_g15_c02': 3,
#  'v_Archery_g15_c03': 3,
#  'v_Archery_g15_c04': 3,
#  'v_Archery_g15_c05': 3,
#  'v_Archery_g15_c06': 3,
#  'v_Archery_g15_c07': 3,
#  'v_Archery_g16_c01': 3,
#  'v_Archery_g16_c02': 3,
#  'v_Archery_g16_c03': 3,
#  'v_Archery_g16_c04': 3,
#  'v_Archery_g16_c05': 3,
#  'v_Archery_g17_c01': 3,
#  'v_Archery_g17_c02': 3,
#  'v_Archery_g17_c03': 3,
#  'v_Archery_g17_c04': 3,
#  'v_Archery_g18_c01': 3,
#  'v_Archery_g18_c02': 3,
#  'v_Archery_g18_c03': 3,
#  'v_Archery_g18_c04': 3,
#  'v_Archery_g18_c05': 3,
#  'v_Archery_g18_c06': 3,
#  'v_Archery_g18_c07': 3,
#  'v_Archery_g19_c01': 3,
#  'v_Archery_g19_c02': 3,
#  'v_Archery_g19_c03': 3,
#  'v_Archery_g19_c04': 3,
#  'v_Archery_g20_c01': 3,
#  'v_Archery_g20_c02': 3,
#  'v_Archery_g20_c03': 3,
#  'v_Archery_g20_c04': 3,
#  'v_Archery_g20_c05': 3,
#  'v_Archery_g20_c06': 3,
#  'v_Archery_g20_c07': 3,
#  'v_Archery_g21_c01': 3,
#  'v_Archery_g21_c02': 3,
#  'v_Archery_g21_c03': 3,
#  'v_Archery_g21_c04': 3,
#  'v_Archery_g22_c01': 3,
#  'v_Archery_g22_c02': 3,
#  'v_Archery_g22_c03': 3,
#  'v_Archery_g22_c04': 3,
#  'v_Archery_g22_c05': 3,
#  'v_Archery_g23_c01': 3,
#  'v_Archery_g23_c02': 3,
#  'v_Archery_g23_c03': 3,
#  'v_Archery_g23_c04': 3,
#  'v_Archery_g23_c05': 3,
#  'v_Archery_g23_c06': 3,
#  'v_Archery_g23_c07': 3,
#  'v_Archery_g24_c01': 3,
#  'v_Archery_g24_c02': 3,
#  'v_Archery_g24_c03': 3,
#  'v_Archery_g24_c04': 3,
#  'v_Archery_g24_c05': 3,
#  'v_Archery_g24_c06': 3,
#  'v_Archery_g25_c01': 3,
#  'v_Archery_g25_c02': 3,
#  'v_Archery_g25_c03': 3,
#  'v_Archery_g25_c04': 3,
#  'v_Archery_g25_c05': 3,
#  'v_Archery_g25_c06': 3,
#  'v_Archery_g25_c07': 3,
#  'v_BabyCrawling_g08_c01': 4,
#  'v_BabyCrawling_g08_c02': 4,
#  'v_BabyCrawling_g08_c03': 4,
#  'v_BabyCrawling_g08_c04': 4,
#  'v_BabyCrawling_g09_c01': 4,
#  'v_BabyCrawling_g09_c02': 4,
#  'v_BabyCrawling_g09_c03': 4,
#  'v_BabyCrawling_g09_c04': 4,
#  'v_BabyCrawling_g09_c05': 4,
#  'v_BabyCrawling_g09_c06': 4,
#  'v_BabyCrawling_g10_c01': 4,
#  'v_BabyCrawling_g10_c02': 4,
#  'v_BabyCrawling_g10_c03': 4,
#  'v_BabyCrawling_g10_c04': 4,
#  'v_BabyCrawling_g10_c05': 4,
#  'v_BabyCrawling_g11_c01': 4,
#  'v_BabyCrawling_g11_c02': 4,
#  'v_BabyCrawling_g11_c03': 4,
#  'v_BabyCrawling_g11_c04': 4,
#  'v_BabyCrawling_g12_c01': 4,
#  'v_BabyCrawling_g12_c02': 4,
#  'v_BabyCrawling_g12_c03': 4,
#  'v_BabyCrawling_g12_c04': 4,
#  'v_BabyCrawling_g12_c05': 4,
#  'v_BabyCrawling_g12_c06': 4,
#  'v_BabyCrawling_g13_c01': 4,
#  'v_BabyCrawling_g13_c02': 4,
#  'v_BabyCrawling_g13_c03': 4,
#  'v_BabyCrawling_g13_c04': 4,
#  'v_BabyCrawling_g13_c05': 4,
#  'v_BabyCrawling_g13_c06': 4,
#  'v_BabyCrawling_g14_c01': 4,
#  'v_BabyCrawling_g14_c02': 4,
#  'v_BabyCrawling_g14_c03': 4,
#  'v_BabyCrawling_g14_c04': 4,
#  'v_BabyCrawling_g15_c01': 4,
#  'v_BabyCrawling_g15_c02': 4,
#  'v_BabyCrawling_g15_c03': 4,
#  'v_BabyCrawling_g15_c04': 4,
#  'v_BabyCrawling_g15_c05': 4,
#  'v_BabyCrawling_g15_c06': 4,
#  'v_BabyCrawling_g16_c01': 4,
#  'v_BabyCrawling_g16_c02': 4,
#  'v_BabyCrawling_g16_c03': 4,
#  'v_BabyCrawling_g16_c04': 4,
#  'v_BabyCrawling_g16_c05': 4,
#  'v_BabyCrawling_g16_c06': 4,
#  'v_BabyCrawling_g17_c01': 4,
#  'v_BabyCrawling_g17_c02': 4,
#  'v_BabyCrawling_g17_c03': 4,
#  'v_BabyCrawling_g17_c04': 4,
#  'v_BabyCrawling_g17_c05': 4,
#  'v_BabyCrawling_g18_c01': 4,
#  'v_BabyCrawling_g18_c02': 4,
#  'v_BabyCrawling_g18_c03': 4,
#  'v_BabyCrawling_g18_c04': 4,
#  'v_BabyCrawling_g18_c05': 4,
#  'v_BabyCrawling_g18_c06': 4,
#  'v_BabyCrawling_g19_c01': 4,
#  'v_BabyCrawling_g19_c02': 4,
#  'v_BabyCrawling_g19_c03': 4,
#  'v_BabyCrawling_g19_c04': 4,
#  'v_BabyCrawling_g19_c05': 4,
#  'v_BabyCrawling_g20_c01': 4,
#  'v_BabyCrawling_g20_c02': 4,
#  'v_BabyCrawling_g20_c03': 4,
#  'v_BabyCrawling_g20_c04': 4,
#  'v_BabyCrawling_g20_c05': 4,
#  'v_BabyCrawling_g20_c06': 4,
#  'v_BabyCrawling_g20_c07': 4,
#  'v_BabyCrawling_g21_c01': 4,
#  'v_BabyCrawling_g21_c02': 4,
#  'v_BabyCrawling_g21_c03': 4,
#  'v_BabyCrawling_g21_c04': 4,
#  'v_BabyCrawling_g22_c01': 4,
#  'v_BabyCrawling_g22_c02': 4,
#  'v_BabyCrawling_g22_c03': 4,
#  'v_BabyCrawling_g22_c04': 4,
#  'v_BabyCrawling_g22_c05': 4,
#  'v_BabyCrawling_g22_c06': 4,
#  'v_BabyCrawling_g22_c07': 4,
#  'v_BabyCrawling_g23_c01': 4,
#  'v_BabyCrawling_g23_c02': 4,
#  'v_BabyCrawling_g23_c03': 4,
#  'v_BabyCrawling_g23_c04': 4,
#  'v_BabyCrawling_g24_c01': 4,
#  'v_BabyCrawling_g24_c02': 4,
#  'v_BabyCrawling_g24_c03': 4,
#  'v_BabyCrawling_g24_c04': 4,
#  'v_BabyCrawling_g24_c05': 4,
#  'v_BabyCrawling_g24_c06': 4,
#  'v_BabyCrawling_g25_c01': 4,
#  'v_BabyCrawling_g25_c02': 4,
#  'v_BabyCrawling_g25_c03': 4,
#  'v_BabyCrawling_g25_c04': 4,
#  'v_BabyCrawling_g25_c05': 4,
#  'v_BabyCrawling_g25_c06': 4,
#  'v_BalanceBeam_g08_c01': 5,
#  'v_BalanceBeam_g08_c02': 5,
#  'v_BalanceBeam_g08_c03': 5,
#  'v_BalanceBeam_g08_c04': 5,
#  'v_BalanceBeam_g09_c01': 5,
#  'v_BalanceBeam_g09_c02': 5,
#  'v_BalanceBeam_g09_c03': 5,
#  'v_BalanceBeam_g09_c04': 5,
#  'v_BalanceBeam_g10_c01': 5,
#  'v_BalanceBeam_g10_c02': 5,
#  'v_BalanceBeam_g10_c03': 5,
#  'v_BalanceBeam_g10_c04': 5,
#  'v_BalanceBeam_g11_c01': 5,
#  'v_BalanceBeam_g11_c02': 5,
#  'v_BalanceBeam_g11_c03': 5,
#  'v_BalanceBeam_g11_c04': 5,
#  'v_BalanceBeam_g12_c01': 5,
#  'v_BalanceBeam_g12_c02': 5,
#  'v_BalanceBeam_g12_c03': 5,
#  'v_BalanceBeam_g12_c04': 5,
#  'v_BalanceBeam_g13_c01': 5,
#  'v_BalanceBeam_g13_c02': 5,
#  'v_BalanceBeam_g13_c03': 5,
#  'v_BalanceBeam_g13_c04': 5,
#  'v_BalanceBeam_g13_c05': 5,
#  'v_BalanceBeam_g14_c01': 5,
#  'v_BalanceBeam_g14_c02': 5,
#  'v_BalanceBeam_g14_c03': 5,
#  'v_BalanceBeam_g14_c04': 5,
#  'v_BalanceBeam_g15_c01': 5,
#  'v_BalanceBeam_g15_c02': 5,
#  'v_BalanceBeam_g15_c03': 5,
#  'v_BalanceBeam_g15_c04': 5,
#  'v_BalanceBeam_g16_c01': 5,
#  'v_BalanceBeam_g16_c02': 5,
#  'v_BalanceBeam_g16_c03': 5,
#  'v_BalanceBeam_g16_c04': 5,
#  'v_BalanceBeam_g17_c01': 5,
#  'v_BalanceBeam_g17_c02': 5,
#  'v_BalanceBeam_g17_c03': 5,
#  'v_BalanceBeam_g17_c04': 5,
#  'v_BalanceBeam_g17_c05': 5,
#  'v_BalanceBeam_g17_c06': 5,
#  'v_BalanceBeam_g18_c01': 5,
#  'v_BalanceBeam_g18_c02': 5,
#  'v_BalanceBeam_g18_c03': 5,
#  'v_BalanceBeam_g18_c04': 5,
#  'v_BalanceBeam_g19_c01': 5,
#  'v_BalanceBeam_g19_c02': 5,
#  'v_BalanceBeam_g19_c03': 5,
#  'v_BalanceBeam_g19_c04': 5,
#  'v_BalanceBeam_g20_c01': 5,
#  'v_BalanceBeam_g20_c02': 5,
#  'v_BalanceBeam_g20_c03': 5,
#  'v_BalanceBeam_g20_c04': 5,
#  'v_BalanceBeam_g21_c01': 5,
#  'v_BalanceBeam_g21_c02': 5,
#  'v_BalanceBeam_g21_c03': 5,
#  'v_BalanceBeam_g21_c04': 5,
#  'v_BalanceBeam_g21_c05': 5,
#  'v_BalanceBeam_g22_c01': 5,
#  'v_BalanceBeam_g22_c02': 5,
#  'v_BalanceBeam_g22_c03': 5,
#  'v_BalanceBeam_g22_c04': 5,
#  'v_BalanceBeam_g23_c01': 5,
#  'v_BalanceBeam_g23_c02': 5,
#  'v_BalanceBeam_g23_c03': 5,
#  'v_BalanceBeam_g23_c04': 5,
#  'v_BalanceBeam_g23_c05': 5,
#  'v_BalanceBeam_g24_c01': 5,
#  'v_BalanceBeam_g24_c02': 5,
#  'v_BalanceBeam_g24_c03': 5,
#  'v_BalanceBeam_g24_c04': 5,
#  'v_BalanceBeam_g25_c01': 5,
#  'v_BalanceBeam_g25_c02': 5,
#  'v_BalanceBeam_g25_c03': 5,
#  'v_BalanceBeam_g25_c04': 5,
#  'v_BandMarching_g08_c01': 6,
#  'v_BandMarching_g08_c02': 6,
#  'v_BandMarching_g08_c03': 6,
#  'v_BandMarching_g08_c04': 6,
#  'v_BandMarching_g08_c05': 6,
#  'v_BandMarching_g08_c06': 6,
#  'v_BandMarching_g08_c07': 6,
#  'v_BandMarching_g09_c01': 6,
#  'v_BandMarching_g09_c02': 6,
#  'v_BandMarching_g09_c03': 6,
#  'v_BandMarching_g09_c04': 6,
#  'v_BandMarching_g09_c05': 6,
#  'v_BandMarching_g09_c06': 6,
#  'v_BandMarching_g09_c07': 6,
#  'v_BandMarching_g10_c01': 6,
#  'v_BandMarching_g10_c02': 6,
#  'v_BandMarching_g10_c03': 6,
#  'v_BandMarching_g10_c04': 6,
#  'v_BandMarching_g10_c05': 6,
#  'v_BandMarching_g10_c06': 6,
#  'v_BandMarching_g10_c07': 6,
#  'v_BandMarching_g11_c01': 6,
#  'v_BandMarching_g11_c02': 6,
#  'v_BandMarching_g11_c03': 6,
#  'v_BandMarching_g11_c04': 6,
#  'v_BandMarching_g11_c05': 6,
#  'v_BandMarching_g11_c06': 6,
#  'v_BandMarching_g11_c07': 6,
#  'v_BandMarching_g12_c01': 6,
#  'v_BandMarching_g12_c02': 6,
#  'v_BandMarching_g12_c03': 6,
#  'v_BandMarching_g12_c04': 6,
#  'v_BandMarching_g12_c05': 6,
#  'v_BandMarching_g12_c06': 6,
#  'v_BandMarching_g13_c01': 6,
#  'v_BandMarching_g13_c02': 6,
#  'v_BandMarching_g13_c03': 6,
#  'v_BandMarching_g13_c04': 6,
#  'v_BandMarching_g13_c05': 6,
#  'v_BandMarching_g14_c01': 6,
#  'v_BandMarching_g14_c02': 6,
#  'v_BandMarching_g14_c03': 6,
#  'v_BandMarching_g14_c04': 6,
#  'v_BandMarching_g14_c05': 6,
#  'v_BandMarching_g14_c06': 6,
#  'v_BandMarching_g15_c01': 6,
#  'v_BandMarching_g15_c02': 6,
#  'v_BandMarching_g15_c03': 6,
#  'v_BandMarching_g15_c04': 6,
#  'v_BandMarching_g15_c05': 6,
#  'v_BandMarching_g15_c06': 6,
#  'v_BandMarching_g15_c07': 6,
#  'v_BandMarching_g16_c01': 6,
#  'v_BandMarching_g16_c02': 6,
#  'v_BandMarching_g16_c03': 6,
#  'v_BandMarching_g16_c04': 6,
#  'v_BandMarching_g16_c05': 6,
#  'v_BandMarching_g16_c06': 6,
#  'v_BandMarching_g16_c07': 6,
#  'v_BandMarching_g17_c01': 6,
#  'v_BandMarching_g17_c02': 6,
#  'v_BandMarching_g17_c03': 6,
#  'v_BandMarching_g17_c04': 6,
#  'v_BandMarching_g18_c01': 6,
#  'v_BandMarching_g18_c02': 6,
#  'v_BandMarching_g18_c03': 6,
#  'v_BandMarching_g18_c04': 6,
#  'v_BandMarching_g18_c05': 6,
#  'v_BandMarching_g18_c06': 6,
#  'v_BandMarching_g19_c01': 6,
#  'v_BandMarching_g19_c02': 6,
#  'v_BandMarching_g19_c03': 6,
#  'v_BandMarching_g19_c04': 6,
#  'v_BandMarching_g19_c05': 6,
#  'v_BandMarching_g19_c06': 6,
#  'v_BandMarching_g19_c07': 6,
#  'v_BandMarching_g20_c01': 6,
#  'v_BandMarching_g20_c02': 6,
#  'v_BandMarching_g20_c03': 6,
#  'v_BandMarching_g20_c04': 6,
#  'v_BandMarching_g20_c05': 6,
#  'v_BandMarching_g20_c06': 6,
#  'v_BandMarching_g21_c01': 6,
#  'v_BandMarching_g21_c02': 6,
#  'v_BandMarching_g21_c03': 6,
#  'v_BandMarching_g21_c04': 6,
#  'v_BandMarching_g21_c05': 6,
#  'v_BandMarching_g21_c06': 6,
#  'v_BandMarching_g22_c01': 6,
#  'v_BandMarching_g22_c02': 6,
#  'v_BandMarching_g22_c03': 6,
#  'v_BandMarching_g22_c04': 6,
#  'v_BandMarching_g22_c05': 6,
#  'v_BandMarching_g23_c01': 6,
#  'v_BandMarching_g23_c02': 6,
#  'v_BandMarching_g23_c03': 6,
#  'v_BandMarching_g23_c04': 6,
#  'v_BandMarching_g23_c05': 6,
#  'v_BandMarching_g23_c06': 6,
#  'v_BandMarching_g24_c01': 6,
#  'v_BandMarching_g24_c02': 6,
#  'v_BandMarching_g24_c03': 6,
#  'v_BandMarching_g24_c04': 6,
#  'v_BandMarching_g24_c05': 6,
#  'v_BandMarching_g24_c06': 6,
#  'v_BandMarching_g25_c01': 6,
#  'v_BandMarching_g25_c02': 6,
#  'v_BandMarching_g25_c03': 6,
#  'v_BandMarching_g25_c04': 6,
#  'v_BandMarching_g25_c05': 6,
#  'v_BandMarching_g25_c06': 6,
#  'v_BandMarching_g25_c07': 6,
#  'v_BaseballPitch_g08_c01': 7,
#  'v_BaseballPitch_g08_c02': 7,
#  'v_BaseballPitch_g08_c03': 7,
#  'v_BaseballPitch_g08_c04': 7,
#  'v_BaseballPitch_g08_c05': 7,
#  'v_BaseballPitch_g08_c06': 7,
#  'v_BaseballPitch_g08_c07': 7,
#  'v_BaseballPitch_g09_c01': 7,
#  'v_BaseballPitch_g09_c02': 7,
#  'v_BaseballPitch_g09_c03': 7,
#  'v_BaseballPitch_g09_c04': 7,
#  'v_BaseballPitch_g09_c05': 7,
#  'v_BaseballPitch_g09_c06': 7,
#  'v_BaseballPitch_g09_c07': 7,
#  'v_BaseballPitch_g10_c01': 7,
#  'v_BaseballPitch_g10_c02': 7,
#  'v_BaseballPitch_g10_c03': 7,
#  'v_BaseballPitch_g10_c04': 7,
#  'v_BaseballPitch_g10_c05': 7,
#  'v_BaseballPitch_g11_c01': 7,
#  'v_BaseballPitch_g11_c02': 7,
#  'v_BaseballPitch_g11_c03': 7,
#  'v_BaseballPitch_g11_c04': 7,
#  'v_BaseballPitch_g11_c05': 7,
#  'v_BaseballPitch_g12_c01': 7,
#  'v_BaseballPitch_g12_c02': 7,
#  'v_BaseballPitch_g12_c03': 7,
#  'v_BaseballPitch_g12_c04': 7,
#  'v_BaseballPitch_g13_c01': 7,
#  'v_BaseballPitch_g13_c02': 7,
#  'v_BaseballPitch_g13_c03': 7,
#  'v_BaseballPitch_g13_c04': 7,
#  'v_BaseballPitch_g13_c05': 7,
#  'v_BaseballPitch_g13_c06': 7,
#  'v_BaseballPitch_g13_c07': 7,
#  'v_BaseballPitch_g14_c01': 7,
#  'v_BaseballPitch_g14_c02': 7,
#  'v_BaseballPitch_g14_c03': 7,
#  'v_BaseballPitch_g14_c04': 7,
#  'v_BaseballPitch_g15_c01': 7,
#  'v_BaseballPitch_g15_c02': 7,
#  'v_BaseballPitch_g15_c03': 7,
#  'v_BaseballPitch_g15_c04': 7,
#  'v_BaseballPitch_g15_c05': 7,
#  'v_BaseballPitch_g15_c06': 7,
#  'v_BaseballPitch_g15_c07': 7,
#  'v_BaseballPitch_g16_c01': 7,
#  'v_BaseballPitch_g16_c02': 7,
#  'v_BaseballPitch_g16_c03': 7,
#  'v_BaseballPitch_g16_c04': 7,
#  'v_BaseballPitch_g16_c05': 7,
#  'v_BaseballPitch_g16_c06': 7,
#  'v_BaseballPitch_g17_c01': 7,
#  'v_BaseballPitch_g17_c02': 7,
#  'v_BaseballPitch_g17_c03': 7,
#  'v_BaseballPitch_g17_c04': 7,
#  'v_BaseballPitch_g17_c05': 7,
#  'v_BaseballPitch_g17_c06': 7,
#  'v_BaseballPitch_g17_c07': 7,
#  'v_BaseballPitch_g18_c01': 7,
#  'v_BaseballPitch_g18_c02': 7,
#  'v_BaseballPitch_g18_c03': 7,
#  'v_BaseballPitch_g18_c04': 7,
#  'v_BaseballPitch_g18_c05': 7,
#  'v_BaseballPitch_g18_c06': 7,
#  'v_BaseballPitch_g18_c07': 7,
#  'v_BaseballPitch_g19_c01': 7,
#  'v_BaseballPitch_g19_c02': 7,
#  'v_BaseballPitch_g19_c03': 7,
#  'v_BaseballPitch_g19_c04': 7,
#  'v_BaseballPitch_g19_c05': 7,
#  'v_BaseballPitch_g20_c01': 7,
#  'v_BaseballPitch_g20_c02': 7,
#  'v_BaseballPitch_g20_c03': 7,
#  'v_BaseballPitch_g20_c04': 7,
#  'v_BaseballPitch_g21_c01': 7,
#  'v_BaseballPitch_g21_c02': 7,
#  'v_BaseballPitch_g21_c03': 7,
#  'v_BaseballPitch_g21_c04': 7,
#  'v_BaseballPitch_g22_c01': 7,
#  'v_BaseballPitch_g22_c02': 7,
#  'v_BaseballPitch_g22_c03': 7,
#  'v_BaseballPitch_g22_c04': 7,
#  'v_BaseballPitch_g22_c05': 7,
#  'v_BaseballPitch_g22_c06': 7,
#  'v_BaseballPitch_g22_c07': 7,
#  'v_BaseballPitch_g23_c01': 7,
#  'v_BaseballPitch_g23_c02': 7,
#  'v_BaseballPitch_g23_c03': 7,
#  'v_BaseballPitch_g23_c04': 7,
#  'v_BaseballPitch_g23_c05': 7,
#  'v_BaseballPitch_g23_c06': 7,
#  'v_BaseballPitch_g23_c07': 7,
#  'v_BaseballPitch_g24_c01': 7,
#  'v_BaseballPitch_g24_c02': 7,
#  'v_BaseballPitch_g24_c03': 7,
#  'v_BaseballPitch_g24_c04': 7,
#  'v_BaseballPitch_g24_c05': 7,
#  'v_BaseballPitch_g24_c06': 7,
#  'v_BaseballPitch_g24_c07': 7,
#  'v_BaseballPitch_g25_c01': 7,
#  'v_BaseballPitch_g25_c02': 7,
#  'v_BaseballPitch_g25_c03': 7,
#  'v_BaseballPitch_g25_c04': 7,
#  'v_BaseballPitch_g25_c05': 7,
#  'v_BaseballPitch_g25_c06': 7,
#  'v_BaseballPitch_g25_c07': 7,
#  'v_Basketball_g08_c01': 8,
#  'v_Basketball_g08_c02': 8,
#  'v_Basketball_g08_c03': 8,
#  'v_Basketball_g08_c04': 8,
#  'v_Basketball_g09_c01': 8,
#  'v_Basketball_g09_c02': 8,
#  'v_Basketball_g09_c03': 8,
#  'v_Basketball_g09_c04': 8,
#  'v_Basketball_g09_c05': 8,
#  'v_Basketball_g10_c01': 8,
#  'v_Basketball_g10_c02': 8,
#  'v_Basketball_g10_c03': 8,
#  'v_Basketball_g10_c04': 8,
#  'v_Basketball_g10_c05': 8,
#  'v_Basketball_g11_c01': 8,
#  'v_Basketball_g11_c02': 8,
#  'v_Basketball_g11_c03': 8,
#  'v_Basketball_g11_c04': 8,
#  'v_Basketball_g11_c05': 8,
#  'v_Basketball_g12_c01': 8,
#  'v_Basketball_g12_c02': 8,
#  'v_Basketball_g12_c03': 8,
#  'v_Basketball_g12_c04': 8,
#  'v_Basketball_g12_c05': 8,
#  'v_Basketball_g13_c01': 8,
#  'v_Basketball_g13_c02': 8,
#  'v_Basketball_g13_c03': 8,
#  'v_Basketball_g13_c04': 8,
#  'v_Basketball_g14_c01': 8,
#  'v_Basketball_g14_c02': 8,
#  'v_Basketball_g14_c03': 8,
#  'v_Basketball_g14_c04': 8,
#  'v_Basketball_g14_c05': 8,
#  'v_Basketball_g15_c01': 8,
#  'v_Basketball_g15_c02': 8,
#  'v_Basketball_g15_c03': 8,
#  'v_Basketball_g15_c04': 8,
#  'v_Basketball_g15_c05': 8,
#  'v_Basketball_g15_c06': 8,
#  'v_Basketball_g15_c07': 8,
#  'v_Basketball_g16_c01': 8,
#  'v_Basketball_g16_c02': 8,
#  'v_Basketball_g16_c03': 8,
#  'v_Basketball_g16_c04': 8,
#  'v_Basketball_g16_c05': 8,
#  'v_Basketball_g16_c06': 8,
#  'v_Basketball_g17_c01': 8,
#  'v_Basketball_g17_c02': 8,
#  'v_Basketball_g17_c03': 8,
#  'v_Basketball_g17_c04': 8,
#  'v_Basketball_g18_c01': 8,
#  'v_Basketball_g18_c02': 8,
#  'v_Basketball_g18_c03': 8,
#  'v_Basketball_g18_c04': 8,
#  'v_Basketball_g18_c05': 8,
#  'v_Basketball_g19_c01': 8,
#  'v_Basketball_g19_c02': 8,
#  'v_Basketball_g19_c03': 8,
#  'v_Basketball_g19_c04': 8,
#  'v_Basketball_g19_c05': 8,
#  'v_Basketball_g19_c06': 8,
#  'v_Basketball_g19_c07': 8,
#  'v_Basketball_g20_c01': 8,
#  'v_Basketball_g20_c02': 8,
#  'v_Basketball_g20_c03': 8,
#  'v_Basketball_g20_c04': 8,
#  'v_Basketball_g20_c05': 8,
#  'v_Basketball_g20_c06': 8,
#  'v_Basketball_g20_c07': 8,
#  'v_Basketball_g21_c01': 8,
#  'v_Basketball_g21_c02': 8,
#  'v_Basketball_g21_c03': 8,
#  'v_Basketball_g21_c04': 8,
#  'v_Basketball_g21_c05': 8,
#  'v_Basketball_g21_c06': 8,
#  'v_Basketball_g22_c01': 8,
#  'v_Basketball_g22_c02': 8,
#  'v_Basketball_g22_c03': 8,
#  'v_Basketball_g22_c04': 8,
#  'v_Basketball_g22_c05': 8,
#  'v_Basketball_g22_c06': 8,
#  'v_Basketball_g22_c07': 8,
#  'v_Basketball_g23_c01': 8,
#  'v_Basketball_g23_c02': 8,
#  'v_Basketball_g23_c03': 8,
#  'v_Basketball_g23_c04': 8,
#  'v_Basketball_g23_c05': 8,
#  'v_Basketball_g23_c06': 8,
#  'v_Basketball_g24_c01': 8,
#  'v_Basketball_g24_c02': 8,
#  'v_Basketball_g24_c03': 8,
#  'v_Basketball_g24_c04': 8,
#  'v_Basketball_g25_c01': 8,
#  'v_Basketball_g25_c02': 8,
#  'v_Basketball_g25_c03': 8,
#  'v_Basketball_g25_c04': 8,
#  'v_Basketball_g25_c05': 8,
#  'v_Basketball_g25_c06': 8,
#  'v_Basketball_g25_c07': 8,
#  'v_BasketballDunk_g08_c01': 9,
#  'v_BasketballDunk_g08_c02': 9,
#  'v_BasketballDunk_g08_c03': 9,
#  'v_BasketballDunk_g08_c04': 9,
#  'v_BasketballDunk_g08_c05': 9,
#  'v_BasketballDunk_g09_c01': 9,
#  'v_BasketballDunk_g09_c02': 9,
#  'v_BasketballDunk_g09_c03': 9,
#  'v_BasketballDunk_g09_c04': 9,
#  'v_BasketballDunk_g09_c05': 9,
#  'v_BasketballDunk_g10_c01': 9,
#  'v_BasketballDunk_g10_c02': 9,
#  'v_BasketballDunk_g10_c03': 9,
#  'v_BasketballDunk_g10_c04': 9,
#  'v_BasketballDunk_g10_c05': 9,
#  'v_BasketballDunk_g11_c01': 9,
#  'v_BasketballDunk_g11_c02': 9,
#  'v_BasketballDunk_g11_c03': 9,
#  'v_BasketballDunk_g11_c04': 9,
#  'v_BasketballDunk_g11_c05': 9,
#  'v_BasketballDunk_g12_c01': 9,
#  'v_BasketballDunk_g12_c02': 9,
#  'v_BasketballDunk_g12_c03': 9,
#  'v_BasketballDunk_g12_c04': 9,
#  'v_BasketballDunk_g12_c05': 9,
#  'v_BasketballDunk_g13_c01': 9,
#  'v_BasketballDunk_g13_c02': 9,
#  'v_BasketballDunk_g13_c03': 9,
#  'v_BasketballDunk_g13_c04': 9,
#  'v_BasketballDunk_g14_c01': 9,
#  'v_BasketballDunk_g14_c02': 9,
#  'v_BasketballDunk_g14_c03': 9,
#  'v_BasketballDunk_g14_c04': 9,
#  'v_BasketballDunk_g14_c05': 9,
#  'v_BasketballDunk_g14_c06': 9,
#  'v_BasketballDunk_g14_c07': 9,
#  'v_BasketballDunk_g15_c01': 9,
#  'v_BasketballDunk_g15_c02': 9,
#  'v_BasketballDunk_g15_c03': 9,
#  'v_BasketballDunk_g15_c04': 9,
#  'v_BasketballDunk_g15_c05': 9,
#  'v_BasketballDunk_g15_c06': 9,
#  'v_BasketballDunk_g15_c07': 9,
#  'v_BasketballDunk_g16_c01': 9,
#  'v_BasketballDunk_g16_c02': 9,
#  'v_BasketballDunk_g16_c03': 9,
#  'v_BasketballDunk_g16_c04': 9,
#  'v_BasketballDunk_g16_c05': 9,
#  'v_BasketballDunk_g16_c06': 9,
#  'v_BasketballDunk_g17_c01': 9,
#  'v_BasketballDunk_g17_c02': 9,
#  'v_BasketballDunk_g17_c03': 9,
#  'v_BasketballDunk_g17_c04': 9,
#  'v_BasketballDunk_g17_c05': 9,
#  'v_BasketballDunk_g17_c06': 9,
#  'v_BasketballDunk_g17_c07': 9,
#  'v_BasketballDunk_g18_c01': 9,
#  'v_BasketballDunk_g18_c02': 9,
#  'v_BasketballDunk_g18_c03': 9,
#  'v_BasketballDunk_g18_c04': 9,
#  'v_BasketballDunk_g18_c05': 9,
#  'v_BasketballDunk_g18_c06': 9,
#  'v_BasketballDunk_g19_c01': 9,
#  'v_BasketballDunk_g19_c02': 9,
#  'v_BasketballDunk_g19_c03': 9,
#  'v_BasketballDunk_g19_c04': 9,
#  'v_BasketballDunk_g20_c01': 9,
#  'v_BasketballDunk_g20_c02': 9,
#  'v_BasketballDunk_g20_c03': 9,
#  'v_BasketballDunk_g20_c04': 9,
#  'v_BasketballDunk_g20_c05': 9,
#  'v_BasketballDunk_g20_c06': 9,
#  'v_BasketballDunk_g21_c01': 9,
#  'v_BasketballDunk_g21_c02': 9,
#  'v_BasketballDunk_g21_c03': 9,
#  'v_BasketballDunk_g21_c04': 9,
#  'v_BasketballDunk_g22_c01': 9,
#  'v_BasketballDunk_g22_c02': 9,
#  'v_BasketballDunk_g22_c03': 9,
#  'v_BasketballDunk_g22_c04': 9,
#  'v_BasketballDunk_g23_c01': 9,
#  'v_BasketballDunk_g23_c02': 9,
#  'v_BasketballDunk_g23_c03': 9,
#  'v_BasketballDunk_g23_c04': 9,
#  'v_BasketballDunk_g23_c05': 9,
#  'v_BasketballDunk_g24_c01': 9,
#  'v_BasketballDunk_g24_c02': 9,
#  'v_BasketballDunk_g24_c03': 9,
#  'v_BasketballDunk_g24_c04': 9,
#  'v_BasketballDunk_g24_c05': 9,
#  'v_BasketballDunk_g25_c01': 9,
#  'v_BasketballDunk_g25_c02': 9,
#  'v_BasketballDunk_g25_c03': 9,
#  'v_BasketballDunk_g25_c04': 9,
#  'v_BenchPress_g08_c01': 10,
#  'v_BenchPress_g08_c02': 10,
#  'v_BenchPress_g08_c03': 10,
#  'v_BenchPress_g08_c04': 10,
#  'v_BenchPress_g08_c05': 10,
#  'v_BenchPress_g08_c06': 10,
#  'v_BenchPress_g08_c07': 10,
#  'v_BenchPress_g09_c01': 10,
#  'v_BenchPress_g09_c02': 10,
#  'v_BenchPress_g09_c03': 10,
#  'v_BenchPress_g09_c04': 10,
#  'v_BenchPress_g09_c05': 10,
#  'v_BenchPress_g09_c06': 10,
#  'v_BenchPress_g09_c07': 10,
#  'v_BenchPress_g10_c01': 10,
#  'v_BenchPress_g10_c02': 10,
#  'v_BenchPress_g10_c03': 10,
#  'v_BenchPress_g10_c04': 10,
#  'v_BenchPress_g11_c01': 10,
#  'v_BenchPress_g11_c02': 10,
#  'v_BenchPress_g11_c03': 10,
#  'v_BenchPress_g11_c04': 10,
#  'v_BenchPress_g11_c05': 10,
#  'v_BenchPress_g12_c01': 10,
#  'v_BenchPress_g12_c02': 10,
#  'v_BenchPress_g12_c03': 10,
#  'v_BenchPress_g12_c04': 10,
#  'v_BenchPress_g12_c05': 10,
#  'v_BenchPress_g12_c06': 10,
#  'v_BenchPress_g12_c07': 10,
#  'v_BenchPress_g13_c01': 10,
#  'v_BenchPress_g13_c02': 10,
#  'v_BenchPress_g13_c03': 10,
#  'v_BenchPress_g13_c04': 10,
#  'v_BenchPress_g13_c05': 10,
#  'v_BenchPress_g13_c06': 10,
#  'v_BenchPress_g13_c07': 10,
#  'v_BenchPress_g14_c01': 10,
#  'v_BenchPress_g14_c02': 10,
#  'v_BenchPress_g14_c03': 10,
#  'v_BenchPress_g14_c04': 10,
#  'v_BenchPress_g14_c05': 10,
#  'v_BenchPress_g14_c06': 10,
#  'v_BenchPress_g14_c07': 10,
#  'v_BenchPress_g15_c01': 10,
#  'v_BenchPress_g15_c02': 10,
#  'v_BenchPress_g15_c03': 10,
#  'v_BenchPress_g15_c04': 10,
#  'v_BenchPress_g15_c05': 10,
#  'v_BenchPress_g15_c06': 10,
#  'v_BenchPress_g16_c01': 10,
#  'v_BenchPress_g16_c02': 10,
#  'v_BenchPress_g16_c03': 10,
#  'v_BenchPress_g16_c04': 10,
#  'v_BenchPress_g16_c05': 10,
#  'v_BenchPress_g17_c01': 10,
#  'v_BenchPress_g17_c02': 10,
#  'v_BenchPress_g17_c03': 10,
#  'v_BenchPress_g17_c04': 10,
#  'v_BenchPress_g17_c05': 10,
#  'v_BenchPress_g17_c06': 10,
#  'v_BenchPress_g17_c07': 10,
#  'v_BenchPress_g18_c01': 10,
#  'v_BenchPress_g18_c02': 10,
#  'v_BenchPress_g18_c03': 10,
#  'v_BenchPress_g18_c04': 10,
#  'v_BenchPress_g18_c05': 10,
#  'v_BenchPress_g18_c06': 10,
#  'v_BenchPress_g18_c07': 10,
#  'v_BenchPress_g19_c01': 10,
#  'v_BenchPress_g19_c02': 10,
#  'v_BenchPress_g19_c03': 10,
#  'v_BenchPress_g19_c04': 10,
#  'v_BenchPress_g19_c05': 10,
#  'v_BenchPress_g19_c06': 10,
#  'v_BenchPress_g20_c01': 10,
#  'v_BenchPress_g20_c02': 10,
#  'v_BenchPress_g20_c03': 10,
#  'v_BenchPress_g20_c04': 10,
#  'v_BenchPress_g20_c05': 10,
#  'v_BenchPress_g20_c06': 10,
#  'v_BenchPress_g20_c07': 10,
#  'v_BenchPress_g21_c01': 10,
#  'v_BenchPress_g21_c02': 10,
#  'v_BenchPress_g21_c03': 10,
#  'v_BenchPress_g21_c04': 10,
#  'v_BenchPress_g22_c01': 10,
#  'v_BenchPress_g22_c02': 10,
#  'v_BenchPress_g22_c03': 10,
#  'v_BenchPress_g22_c04': 10,
#  'v_BenchPress_g22_c05': 10,
#  'v_BenchPress_g22_c06': 10,
#  'v_BenchPress_g22_c07': 10,
#  'v_BenchPress_g23_c01': 10,
#  'v_BenchPress_g23_c02': 10,
#  'v_BenchPress_g23_c03': 10,
#  'v_BenchPress_g23_c04': 10,
#  'v_BenchPress_g23_c05': 10,
#  'v_BenchPress_g24_c01': 10,
#  'v_BenchPress_g24_c02': 10,
#  'v_BenchPress_g24_c03': 10,
#  'v_BenchPress_g24_c04': 10,
#  'v_BenchPress_g24_c05': 10,
#  'v_BenchPress_g24_c06': 10,
#  'v_BenchPress_g24_c07': 10,
#  'v_BenchPress_g25_c01': 10,
#  'v_BenchPress_g25_c02': 10,
#  'v_BenchPress_g25_c03': 10,
#  'v_BenchPress_g25_c04': 10,
#  'v_BenchPress_g25_c05': 10,
#  'v_BenchPress_g25_c06': 10,
#  'v_BenchPress_g25_c07': 10,
#  'v_Biking_g08_c01': 11,
#  'v_Biking_g08_c02': 11,
#  'v_Biking_g08_c03': 11,
#  'v_Biking_g08_c04': 11,
#  'v_Biking_g08_c05': 11,
#  'v_Biking_g08_c06': 11,
#  'v_Biking_g09_c01': 11,
#  'v_Biking_g09_c02': 11,
#  'v_Biking_g09_c03': 11,
#  'v_Biking_g09_c04': 11,
#  'v_Biking_g10_c01': 11,
#  'v_Biking_g10_c02': 11,
#  'v_Biking_g10_c03': 11,
#  'v_Biking_g10_c04': 11,
#  'v_Biking_g10_c05': 11,
#  ...}

# %% [markdown]
# ## Now we want to try to the generator

# %%
datagen = DataGenerator(IDs, labels, **params)

# %%
for X, y in datagen:
    print(X.shape)
# Out:
# (64, 224, 224, 3)
# (64, 224, 224, 3)
# (64, 224, 224, 3)
# (64, 224, 224, 3)
# (64, 224, 224, 3)
# (64, 224, 224, 3)
# (64, 224, 224, 3)
# (64, 224, 224, 3)
# (64, 224, 224, 3)
# (64, 224, 224, 3)
# (64, 224, 224, 3)
# (64, 224, 224, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1c24f0ac88cb> in <module>()
# ----> 1 for X, y in datagen:
#       2     print(X.shape)
#       3
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/utils/data_utils.py in __iter__(self)
#     370         """Create an infinite generator that iterate over the Sequence."""
#     371         while True:
# --> 372             for item in (self[i] for i in range(len(self))):
#     373                 yield item
#     374
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/utils/data_utils.py in <genexpr>(.0)
#     370         """Create an infinite generator that iterate over the Sequence."""
#     371         while True:
# --> 372             for item in (self[i] for i in range(len(self))):
#     373                 yield item
#     374
#
# ~/su_buildup/su_buildup/keras_data_generator/ucf101_datagenerator/generator_class.py in __getitem__(self, index)
#      32
#      33         # Generate data
# ---> 34         X, y = self.__data_generation(list_IDs_temp)
#      35
#      36         return X, y
#
# ~/su_buildup/su_buildup/keras_data_generator/ucf101_datagenerator/generator_class.py in __data_generation(self, list_IDs_temp)
#      49         # Generate data
#      50         for i, ID in enumerate(list_IDs_temp):
# ---> 51             X[i,] = self.__data_load(ID)
#      52             y[i] = self.labels[ID]-1
#      53
#
# KeyboardInterrupt:

# %%
len(labels)
